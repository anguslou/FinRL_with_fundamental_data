# %% [markdown]
# <a href="https://colab.research.google.com/github/anguslou/FinRL_with_fundamental_data/blob/main/fundmental_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yahooquery
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from yahooquery import Ticker
import pandas as pd

# %%
symbol = 'AAPL'
getData = Ticker(symbol)
summary_details = getData.summary_detail[symbol]
summary_details
# Out:
# {'algorithm': None,
#  'ask': 0.0,
#  'askSize': 800,
#  'averageDailyVolume10Day': 82358450,
#  'averageVolume': 94663683,
#  'averageVolume10days': 82358450,
#  'beta': 1.20009,
#  'bid': 0.0,
#  'bidSize': 1100,
#  'coinMarketCapLink': None,
#  'currency': 'USD',
#  'dayHigh': 139.035,
#  'dayLow': 135.67,
#  'dividendRate': 0.92,
#  'dividendYield': 0.0066000004,
#  'exDividendDate': '2022-05-06 00:00:00',
#  'fiftyDayAverage': 146.3498,
#  'fiftyTwoWeekHigh': 182.94,
#  'fiftyTwoWeekLow': 129.04,
#  'fiveYearAvgDividendYield': 1.07,
#  'forwardPE': 21.210686,
#  'fromCurrency': None,
#  'lastMarket': None,
#  'marketCap': 2248609628160,
#  'maxAge': 1,
#  'open': 136.04,
#  'payoutRatio': 0.14310001,
#  'previousClose': 136.72,
#  'priceHint': 2,
#  'priceToSalesTrailing12Months': 5.825157,
#  'regularMarketDayHigh': 139.035,
#  'regularMarketDayLow': 135.67,
#  'regularMarketOpen': 136.04,
#  'regularMarketPreviousClose': 136.72,
#  'regularMarketVolume': 71051552,
# ...

# %%
PE = summary_details['forwardPE']
PE
# Out:
# 21.210686

# %%
beta = summary_details['beta']
avg_vol = summary_details['averageVolume']

# %%
i_s = getData.income_statement('q',trailing=False)
i_s
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  \
# symbol
# AAPL   2021-06-30         3M          USD        1.662937e+10      1.31
# AAPL   2021-09-30         3M          USD        1.648712e+10      1.25
# AAPL   2021-12-31         3M          USD        1.639172e+10      2.11
# AAPL   2022-03-31         3M          USD        1.627880e+10      1.54
#
#         CostOfRevenue  DilutedAverageShares  DilutedEPS  \
# symbol
# AAPL     4.617900e+10          1.678174e+10        1.30
# AAPL     4.818600e+10          1.663510e+10        1.24
# AAPL     6.970200e+10          1.651929e+10        2.10
# AAPL     5.471900e+10          1.640332e+10        1.52
#
#         DilutedNIAvailtoComStockholders          EBIT  ...  \
# symbol                                                 ...
# AAPL                       2.174400e+10  2.503400e+10  ...
# AAPL                       2.055100e+10  2.392000e+10  ...
# AAPL                       3.463000e+10  4.193500e+10  ...
# ...

# %%
income_statement = pd.DataFrame(i_s).set_index('asOfDate')

income_statement
# Out:
#            periodType currencyCode  BasicAverageShares  BasicEPS  \
# asOfDate
# 2021-06-30         3M          USD        1.662937e+10      1.31
# 2021-09-30         3M          USD        1.648712e+10      1.25
# 2021-12-31         3M          USD        1.639172e+10      2.11
# 2022-03-31         3M          USD        1.627880e+10      1.54
#
#             CostOfRevenue  DilutedAverageShares  DilutedEPS  \
# asOfDate
# 2021-06-30   4.617900e+10          1.678174e+10        1.30
# 2021-09-30   4.818600e+10          1.663510e+10        1.24
# 2021-12-31   6.970200e+10          1.651929e+10        2.10
# 2022-03-31   5.471900e+10          1.640332e+10        1.52
#
#             DilutedNIAvailtoComStockholders          EBIT   GrossProfit  ...  \
# asOfDate                                                                 ...
# 2021-06-30                     2.174400e+10  2.503400e+10  3.525500e+10  ...
# 2021-09-30                     2.055100e+10  2.392000e+10  3.517400e+10  ...
# ...

# %%
date = income_statement.index[-1]
date
# Out:
# Timestamp('2022-03-31 00:00:00')

# %%
EPS = income_statement['DilutedEPS'][date]
EPS
# Out:
# 1.52

# %%
EBIT = income_statement['EBIT'][date]

# %%
profile = getData.asset_profile[symbol]
profile
# Out:
# {'address1': 'One Apple Park Way',
#  'auditRisk': 2,
#  'boardRisk': 1,
#  'city': 'Cupertino',
#  'companyOfficers': [{'age': 60,
#    'exercisedValue': 0,
#    'fiscalYear': 2021,
#    'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'title': 'CEO & Director',
#    'totalPay': 16386559,
#    'unexercisedValue': 0,
#    'yearBorn': 1961},
#   {'age': 57,
#    'exercisedValue': 0,
#    'fiscalYear': 2021,
#    'maxAge': 1,
#    'name': 'Mr. Luca  Maestri',
#    'title': 'CFO & Sr. VP',
#    'totalPay': 5018883,
#    'unexercisedValue': 0,
#    'yearBorn': 1964},
#   {'age': 57,
#    'exercisedValue': 0,
#    'fiscalYear': 2021,
#    'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'title': 'Chief Operating Officer',
#    'totalPay': 5017437,
#    'unexercisedValue': 0,
#    'yearBorn': 1964},
#   {'age': 57,
#    'exercisedValue': 0,
#    'fiscalYear': 2021,
#    'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'title': 'Sr. VP, Gen. Counsel & Sec.',
# ...

# %%
industry = profile['industry']
sector = profile['sector']

# %%
finance_data = getData.financial_data[symbol]
finance_data
# Out:
# {'currentPrice': 138.93,
#  'currentRatio': 0.927,
#  'debtToEquity': 178.016,
#  'earningsGrowth': 0.086,
#  'ebitda': 130633998336,
#  'ebitdaMargins': 0.33842,
#  'financialCurrency': 'USD',
#  'freeCashflow': 84384628736,
#  'grossMargins': 0.43322,
#  'grossProfits': 152836000000,
#  'maxAge': 86400,
#  'numberOfAnalystOpinions': 43,
#  'operatingCashflow': 116425998336,
#  'operatingMargins': 0.30926,
#  'profitMargins': 0.26407,
#  'quickRatio': 0.76,
#  'recommendationKey': 'buy',
#  'recommendationMean': 1.9,
#  'returnOnAssets': 0.21695,
#  'returnOnEquity': 1.49271,
#  'revenueGrowth': 0.086,
#  'revenuePerShare': 23.471,
#  'targetHighPrice': 214.0,
#  'targetLowPrice': 155.0,
#  'targetMeanPrice': 186.73,
#  'targetMedianPrice': 187.37,
#  'totalCash': 51511001088,
#  'totalCashPerShare': 3.183,
#  'totalDebt': 119980998656,
#  'totalRevenue': 386017001472}

# %%
d={}

ebitda = finance_data['ebitda']
quick = finance_data['quickRatio']
debtToEquity = finance_data['debtToEquity']
returnOnAssets = finance_data['returnOnAssets']
returnOnEquity = finance_data['returnOnEquity']
freeCashflow = finance_data['freeCashflow']

targetHighPrice = finance_data['targetHighPrice']

#targetLowPrice = finance_data['targetLowPrice']
#targetMeanPrice = finance_data['targetMeanPrice']
#recommendationKey = finance_data['recommendationKey']

ebitda
# Out:
# 130633998336

# %%
key_stats = getData.key_stats[symbol]
key_stats
# Out:
# {'52WeekChange': -0.021757483,
#  'SandP52WeekChange': -0.11930591,
#  'beta': 1.20009,
#  'bookValue': 4.158,
#  'category': None,
#  'dateShortInterest': '2022-06-15 00:00:00',
#  'earningsQuarterlyGrowth': 0.058,
#  'enterpriseToEbitda': 17.737,
#  'enterpriseToRevenue': 6.003,
#  'enterpriseValue': 2317077184512,
#  'floatShares': 16168348412,
#  'forwardEps': 6.55,
#  'forwardPE': 21.210686,
#  'fundFamily': None,
#  'heldPercentInsiders': 0.00072999997,
#  'heldPercentInstitutions': 0.59629,
#  'impliedSharesOutstanding': 0,
#  'lastDividendDate': 1651795200,
#  'lastDividendValue': 0.23,
#  'lastFiscalYearEnd': '2021-09-25 00:00:00',
#  'lastSplitDate': '2020-08-31 00:00:00',
#  'lastSplitFactor': '4:1',
#  'legalType': None,
#  'maxAge': 1,
#  'mostRecentQuarter': '2022-03-26 00:00:00',
#  'netIncomeToCommon': 101934997504,
#  'nextFiscalYearEnd': '2023-09-25 00:00:00',
#  'pegRatio': 2.29,
#  'priceHint': 2,
#  'priceToBook': 33.412697,
#  'profitMargins': 0.26407,
# ...

# %%
PB = key_stats['priceToBook']
shortRatio = key_stats['shortRatio']
PEG = key_stats['pegRatio']
